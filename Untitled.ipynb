# %% [markdown]
# <a href="https://colab.research.google.com/github/praewery/E-Commerce-ETL-Pipeline-with-Apache-Airflow/blob/master/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "ชื่อ นามสกุล"
print(f"สวัสดีค่ะ ชื่อ{name}และนี่คือโค้ดแรกของgithub")
name = "ชื่อ นามสกุล"
print(f"สวัสดีค่ะ ชื่อ{name}และนี่คือโค้ดแรกของgithub")
# Out:
# สวัสดีค่ะ ชื่อpraewa xxxxxและนี่คือโค้ดแรกของgithub
# สวัสดีค่ะ ชื่อxxxxxx xxxxxและนี่คือโค้ดแรกของgithub
